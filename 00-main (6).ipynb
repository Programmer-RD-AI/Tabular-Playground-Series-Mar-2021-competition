# %%
# !unzip /content/drive/MyDrive/Colab\ Notebooks/Projects/TensorFlow/Competitions/Classification/Tabular-Playground-Series-Mar-2021/data.zip
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/Projects/TensorFlow/Competitions/Classification/Tabular-Playground-Series-Mar-2021/data.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
sub = pd.read_csv('sample_submission.csv')

# %%
data.head()
# Out:
#    id cat0 cat1 cat2 cat3  ...     cont7     cont8     cont9    cont10 target
# 0   0    A    I    A    B  ...  0.791921  0.815254  0.965006  0.665915      0
# 1   1    A    I    A    A  ...  0.408701  0.399353  0.927406  0.493729      0
# 2   2    A    K    A    A  ...  0.388835  0.412303  0.292696  0.549452      0
# 3   3    A    K    A    C  ...  0.897617  0.633669  0.760318  0.934242      0
# 4   4    A    I    G    B  ...  0.279167  0.351103  0.357084  0.328960      1
#
# [5 rows x 32 columns]

# %%
test_data.head()
# Out:
#    id cat0 cat1 cat2 cat3  ...     cont6     cont7     cont8     cont9    cont10
# 0   5    A    F    A    A  ...  0.551249  0.655693  0.598331  0.359987  0.947489
# 1   6    A    H    C    A  ...  0.248987  0.654614  0.347944  0.565520  0.388580
# 2   8    A    N    C    A  ...  0.746740  0.335590  0.341238  0.252289  0.411592
# 3   9    B    L    C    A  ...  0.538724  0.381566  0.481660  0.348514  0.325723
# 4  11    A    F    A    B  ...  0.178920  0.763479  0.562491  0.466261  0.585781
#
# [5 rows x 31 columns]

# %%
sub.head()
# Out:
#    id  target
# 0   5     0.5
# 1   6     0.5
# 2   8     0.5
# 3   9     0.5
# 4  11     0.5

# %%
sub
# Out:
#             id  target
# 0            5     0.5
# 1            6     0.5
# 2            8     0.5
# 3            9     0.5
# 4           11     0.5
# ...        ...     ...
# 199995  499983     0.5
# 199996  499984     0.5
# 199997  499987     0.5
# 199998  499994     0.5
# 199999  499998     0.5
#
# [200000 rows x 2 columns]

# %%
sub['target'].value_counts()
# Out:
# 0.5    200000
# Name: target, dtype: int64

# %%
len(data)
# Out:
# 300000

# %%
data.isna().sum()
# Out:
# id        0
# cat0      0
# cat1      0
# cat2      0
# cat3      0
# cat4      0
# cat5      0
# cat6      0
# cat7      0
# cat8      0
# cat9      0
# cat10     0
# cat11     0
# cat12     0
# cat13     0
# cat14     0
# cat15     0
# cat16     0
# cat17     0
# cat18     0
# cont0     0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# target    0
# dtype: int64

# %%
X = data.drop('target',axis=1)
y = data['target']

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
data.dtypes
# Out:
# id          int64
# cat0       object
# cat1       object
# cat2       object
# cat3       object
# cat4       object
# cat5       object
# cat6       object
# cat7       object
# cat8       object
# cat9       object
# cat10      object
# cat11      object
# cat12      object
# cat13      object
# cat14      object
# cat15      object
# cat16      object
# cat17      object
# cat18      object
# cont0     float64
# cont1     float64
# cont2     float64
# cont3     float64
# cont4     float64
# cont5     float64
# cont6     float64
# cont7     float64
# cont8     float64
# cont9     float64
# cont10    float64
# target      int64
# dtype: object

# %%
minmax_cols = []
for i in range(19):
  minmax_cols.append(f'cat{i}')

# %%
onehot_cols = []
for i in range(11):
  onehot_cols.append(f'cont{i}')

# %%
ct = make_column_transformer(
    (MinMaxScaler(),onehot_cols),
    (OneHotEncoder(handle_unknown='ignore'),minmax_cols)
)
ct.fit(X)
X_train,X_test = ct.transform(X_train),ct.transform(X_test)

# %%
# Modelling

# %%
# !pip3 install wandb

# %%
import tensorflow as tf
import wandb
from wandb.keras import *

# %%
PROJECT_NAME = "Tabular Playground Series - Mar 2021"

# %%
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
# # Classification
# wandb.init(project=PROJECT_NAME,name='baseline')
# baseline = tf.keras.Sequential([
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='sigmoid')
# ])
# baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam())
# baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# # Classification
# wandb.init(project=PROJECT_NAME,name='baseline-0')
# baseline = tf.keras.Sequential([
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='sigmoid')
# ])
# baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam())
# baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# # Classification
# wandb.init(project=PROJECT_NAME,name='baseline-1')
# baseline = tf.keras.Sequential([
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='sigmoid')
# ])
# baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam())
# baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# # Classification
# wandb.init(project=PROJECT_NAME,name='baseline-2')
# baseline = tf.keras.Sequential([
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='sigmoid')
# ])
# baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam())
# baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# # Classification
# wandb.init(project=PROJECT_NAME,name='baseline-3')
# baseline = tf.keras.Sequential([
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='sigmoid')
# ])
# baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam())
# baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# # Classification
# wandb.init(project=PROJECT_NAME,name='baseline-4')
# baseline = tf.keras.Sequential([
#   tf.keras.layers.Dense(1,activation='relu'),
#   tf.keras.layers.Dense(1,activation='sigmoid')
# ])
# baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam())
# baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# total neurons per layer = 1,2,3,4,5,10,15,20,25
# Layers = 1
# Epochs = 125 (With early stopping)
# learning rate = 1.0,0.1,0.01,0.001
# activation type = linear Swish ReLU Tanh selu elu
# optimize = SGD, Adam, Adadelta, Adagrad, Adamax

# %%
# neurons = [1,2,3,4,5,10,15,20,25]
# for neuron in neurons:
#   wandb.init(project=PROJECT_NAME,name=f'{neuron}-neuron')
#   baseline = tf.keras.Sequential([
#     tf.keras.layers.Dense(neuron,activation='relu'),
#     tf.keras.layers.Dense(1,activation='sigmoid')
#   ])
#   baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam())
#   baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# total neurons per layer = 10
# Layers = 1
# Epochs = 100 (With early stopping)
# learning rate = 1.0,0.1,0.01,0.001
# activation type = linear Swish ReLU Tanh selu elu
# optimize = SGD, Adam, Adadelta, Adagrad, Adamax

# %%
# lrs = [1.0,0.1,0.01,0.001]
# for lr in lrs:
#   wandb.init(project=PROJECT_NAME,name=f'{lr}-lr')
#   baseline = tf.keras.Sequential([
#     tf.keras.layers.Dense(1,activation='relu'),
#     tf.keras.layers.Dense(1,activation='sigmoid')
#   ])
#   baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam(lr=lr))
#   baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# total neurons per layer = 10
# Layers = 1
# Epochs = 100 (With early stopping)
# learning rate = 0.001 (1.0,0.1,0.01,0.001)
# activation type = linear Swish ReLU Tanh selu elu
# optimize = SGD, Adam, Adadelta, Adagrad, Adamax

# %%
from tensorflow.keras.optimizers import *
from tensorflow.keras.activations import *

# %%
# ats = ['linear',swish,relu,tanh,selu,elu,None]
# for at in ats:
#   wandb.init(project=PROJECT_NAME,name=f'{at}-at')
#   baseline = tf.keras.Sequential([
#     tf.keras.layers.Dense(1,activation=at),
#     tf.keras.layers.Dense(1,activation='sigmoid')
#   ])
#   baseline.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam(lr=0.001))
#   baseline.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,callbacks=[WandbCallback()])

# %%
# total neurons per layer = 10
# Layers = 1
# Epochs = 100 (With early stopping)
# learning rate =  (1.0,0.1,0.01,0.001)
# activation type = linear Swish ReLU Tanh selu elu
# optimize = SGD, Adam, Adadelta, Adagrad, Adamax

# %%
# Results
# total neurons per layer = 10
# Layers = 1
# Epochs = 100 (With early stopping)
# learning rate = 0.001 (1.0,0.1,0.01,0.001)
# activation type = relu, None (linear Swish ReLU Tanh selu elu)
# optimize = Adam (SGD, Adam, Adadelta, Adagrad, Adamax)

# %%
# wandb.init(project=PROJECT_NAME,name='Big-Dog-Model-1')
# model = tf.keras.Sequential([
#   tf.keras.layers.Dense(10,activation='relu'),
#   tf.keras.layers.Dense(1,activation='sigmoid')
# ])
# model.compile(loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'],optimizer=tf.keras.optimizers.Adam(lr=0.001))
# model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,callbacks=[WandbCallback(),tf.keras.callbacks.EarlyStopping(patience=5)])
# model.save('/content/drive/MyDrive/Colab Notebooks/Projects/TensorFlow/Competitions/Classification/Tabular-Playground-Series-Mar-2021/model_1.h5')

# %%
# !nvidia-smi
# Out:
# Thu Mar 25 15:32:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    78W / 149W |    176MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
sub
# Out:
#             id  target
# 0            5     0.5
# 1            6     0.5
# 2            8     0.5
# 3            9     0.5
# 4           11     0.5
# ...        ...     ...
# 199995  499983     0.5
# 199996  499984     0.5
# 199997  499987     0.5
# 199998  499994     0.5
# 199999  499998     0.5
#
# [200000 rows x 2 columns]

# %%
test_data
# Out:
#             id cat0 cat1 cat2  ...     cont7     cont8     cont9    cont10
# 0            5    A    F    A  ...  0.655693  0.598331  0.359987  0.947489
# 1            6    A    H    C  ...  0.654614  0.347944  0.565520  0.388580
# 2            8    A    N    C  ...  0.335590  0.341238  0.252289  0.411592
# 3            9    B    L    C  ...  0.381566  0.481660  0.348514  0.325723
# 4           11    A    F    A  ...  0.763479  0.562491  0.466261  0.585781
# ...        ...  ...  ...  ...  ...       ...       ...       ...       ...
# 199995  499983    A    N    A  ...  0.319130  0.520681  0.519545  0.427119
# 199996  499984    B    I    A  ...  0.700829  0.531728  0.528427  0.922645
# 199997  499987    A    L    D  ...  0.578641  0.811941  0.537106  0.531758
# 199998  499994    A    K    A  ...  0.369986  0.438712  0.715524  0.381978
# 199999  499998    A    K    A  ...  0.378355  0.547927  0.273595  0.448016
#
# [200000 rows x 31 columns]

# %%
ids = test_data['id']
test_data = ct.transform(test_data)
test_data = test_data.toarray()

# %%
preds = tf.squeeze(tf.round(model.predict(test_data)))

# %%
preds
# Out:
# <tf.Tensor: shape=(200000,), dtype=float32, numpy=array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)>

# %%
import numpy as np
preds = np.array(preds)

# %%
preds
# Out:
# array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)

# %%
ids
# Out:
# 0              5
# 1              6
# 2              8
# 3              9
# 4             11
#            ...
# 199995    499983
# 199996    499984
# 199997    499987
# 199998    499994
# 199999    499998
# Name: id, Length: 200000, dtype: int64

# %%
submission = pd.DataFrame({'id':[],'target':[]})
for pred,id in zip(preds,np.array(ids)):
  submission = submission.append({'id':id,'target':pred},ignore_index=True)

# %%
submission.dtypes
# Out:
# id        float64
# target    float64
# dtype: object

# %%
sub.dtypes
# Out:
# id          int64
# target    float64
# dtype: object

# %%
submission['id'] = submission['id'].astype(int)
submission['target'] = submission['target'].astype(float)

# %%
submission.dtypes
# Out:
# id          int64
# target    float64
# dtype: object

# %%
submission.to_csv('/content/drive/MyDrive/Colab Notebooks/Projects/TensorFlow/Competitions/Classification/Tabular-Playground-Series-Mar-2021/submissions.csv',index=False)
